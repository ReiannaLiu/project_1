# %%
# run this cell to download the data only once
pip install yfinance

# %%
# import Dependencies
import yfinance as yf
import pandas as pd

# %%
top_30_tickers =[
    "PLTR", "TLRY", "TSLA", "LCID", "AAPL", "NIO", 
    "AMD", "AMZN", "RIVN", "F", "BAC", "T",
    "MPW", "NVDA", "AMC", "INTC", "ITUB", "JNJ", 
    "VALE", "SOFI", "MARA", "DDOG", "LYG", "DISH",
    "AAL", "OPEN", "SWN", "PFE", "HPE", "JBLU"
]

# %%
# create a dataframe with the top 30 tickers
top_30_df = pd.DataFrame({"Ticker": top_30_tickers})
top_30_df["company"] = "N/A"
top_30_df["address"] = "N/A"
top_30_df["city"] = "N/A"
top_30_df["state"] = "N/A"
top_30_df["zip"] = "N/A"
top_30_df["country"] = "N/A"


# get the company info for each ticker
for index, row in top_30_df.iterrows():

    top_30_df.loc[index, "company"] = yf.Ticker(row["Ticker"]).info['longName']

    top_30_df.loc[index, "address"] = yf.Ticker(row["Ticker"]).info.get('address1', 'N/A')

    top_30_df.loc[index, "city"] = yf.Ticker(row["Ticker"]).info.get('city', 'N/A')

    top_30_df.loc[index, "state"] = yf.Ticker(row["Ticker"]).info.get('state', 'N/A')

    top_30_df.loc[index, "zip"] = yf.Ticker(row["Ticker"]).info.get('zip', 'N/A')

    top_30_df.loc[index, "country"] = yf.Ticker(row["Ticker"]).info.get('country', 'N/A')

top_30_df
# Out:
#    Ticker                             company  \
# 0    PLTR          Palantir Technologies Inc.
# 1    TLRY                 Tilray Brands, Inc.
# 2    TSLA                         Tesla, Inc.
# 3    LCID                   Lucid Group, Inc.
# 4    AAPL                          Apple Inc.
# 5     NIO                            NIO Inc.
# 6     AMD        Advanced Micro Devices, Inc.
# 7    AMZN                    Amazon.com, Inc.
# 8    RIVN             Rivian Automotive, Inc.
# 9       F                  Ford Motor Company
# 10    BAC         Bank of America Corporation
# 11      T                           AT&T Inc.
# 12    MPW      Medical Properties Trust, Inc.
# 13   NVDA                  NVIDIA Corporation
# 14    AMC    AMC Entertainment Holdings, Inc.
# 15   INTC                   Intel Corporation
# 16   ITUB          Itaú Unibanco Holding S.A.
# 17    JNJ                   Johnson & Johnson
# 18   VALE                           Vale S.A.
# 19   SOFI             SoFi Technologies, Inc.
# 20   MARA     Marathon Digital Holdings, Inc.
# 21   DDOG                       Datadog, Inc.
# 22    LYG            Lloyds Banking Group plc
# 23   DISH            DISH Network Corporation
# 24    AAL        American Airlines Group Inc.
# 25   OPEN          Opendoor Technologies Inc.
# 26    SWN         Southwestern Energy Company
# 27    PFE                         Pfizer Inc.
# 28    HPE  Hewlett Packard Enterprise Company
# 29   JBLU         JetBlue Airways Corporation
#
#                                  address              city state         zip  \
# 0                       1200 17th Street            Denver    CO       80202
# 1                 265 Talbot Street West        Leamington    ON     N8H 5L4
# 2                           1 Tesla Road            Austin    TX       78725
# 3                 7373 Gateway Boulevard            Newark    CA       94560
# 4                     One Apple Park Way         Cupertino    CA       95014
# 5                            Building 20          Shanghai   N/A      201804
# 6                   2485 Augustine Drive       Santa Clara    CA       95054
# 7                 410 Terry Avenue North           Seattle    WA  98109-5210
# 8                      14600 Myford Road            Irvine    CA       92606
# 9                      One American Road          Dearborn    MI  48126-1899
# 10      Bank of America Corporate Center         Charlotte    NC       28255
# 11                208 South Akard Street            Dallas    TX       75202
# 12               1000 Urban Center Drive        Birmingham    AL  35242-2225
# 13             2788 San Tomas Expressway       Santa Clara    CA       95051
# 14                           One AMC Way           Leawood    KS       66211
# 15        2200 Mission College Boulevard       Santa Clara    CA  95054-1549
# 16  Praça Alfredo Egydio de Souza Aranha         São Paulo    SP   04344-902
# 17           One Johnson & Johnson Plaza     New Brunswick    NJ       08933
# 18                 Praia de Botafogo 186    Rio de Janeiro    RJ   22250-145
# 19                        234 1st Street     San Francisco    CA       94105
# 20                   101 NE Third Avenue   Fort Lauderdale    FL       33301
# 21                        620 8th Avenue          New York    NY       10018
# 22                     25 Gresham Street            London   N/A    EC2V 7HN
# 23         9601 South Meridian Boulevard         Englewood    CO       80112
# 24                       1 Skyview Drive        Fort Worth    TX       76155
# 25             410 North Scottsdale Road             Tempe    AZ       85281
# 26                    10000 Energy Drive            Spring    TX       77389
# 27              66 Hudson Boulevard East          New York    NY  10001-2192
# 28             1701 East Mossy Oaks Road            Spring    TX       77389
# 29              27-01 Queens Plaza North  Long Island City    NY       11101
#
#            country
# 0    United States
# 1           Canada
# 2    United States
# 3    United States
# 4    United States
# 5            China
# 6    United States
# 7    United States
# 8    United States
# 9    United States
# 10   United States
# 11   United States
# 12   United States
# 13   United States
# 14   United States
# 15   United States
# 16          Brazil
# 17   United States
# 18          Brazil
# 19   United States
# 20   United States
# 21   United States
# 22  United Kingdom
# 23   United States
# 24   United States
# 25   United States
# 26   United States
# 27   United States
# 28   United States
# 29   United States

# %%
average_manager_age = []

for ticker in top_30_tickers:
    company_officers = yf.Ticker(ticker).info['companyOfficers']

    age_sum = 0
    age_len = len(company_officers)

    for officer in company_officers:
        # Check if 'age' key exists for the current officer
        if 'age' in officer:
            age_sum += officer['age']
        else:
            age_len -= 1

    # If none of the officers have an 'age' key, this will prevent division by zero
    if age_len == 0:
        avg_age = 0
    else:
        avg_age = int(round(age_sum / age_len, 0))
        average_manager_age.append(avg_age)

top_30_df['Average Manager Age'] = average_manager_age

top_30_df
# Out:
#    Ticker                             company  \
# 0    PLTR          Palantir Technologies Inc.
# 1    TLRY                 Tilray Brands, Inc.
# 2    TSLA                         Tesla, Inc.
# 3    LCID                   Lucid Group, Inc.
# 4    AAPL                          Apple Inc.
# 5     NIO                            NIO Inc.
# 6     AMD        Advanced Micro Devices, Inc.
# 7    AMZN                    Amazon.com, Inc.
# 8    RIVN             Rivian Automotive, Inc.
# 9       F                  Ford Motor Company
# 10    BAC         Bank of America Corporation
# 11      T                           AT&T Inc.
# 12    MPW      Medical Properties Trust, Inc.
# 13   NVDA                  NVIDIA Corporation
# 14    AMC    AMC Entertainment Holdings, Inc.
# 15   INTC                   Intel Corporation
# 16   ITUB          Itaú Unibanco Holding S.A.
# 17    JNJ                   Johnson & Johnson
# 18   VALE                           Vale S.A.
# 19   SOFI             SoFi Technologies, Inc.
# 20   MARA     Marathon Digital Holdings, Inc.
# 21   DDOG                       Datadog, Inc.
# 22    LYG            Lloyds Banking Group plc
# 23   DISH            DISH Network Corporation
# 24    AAL        American Airlines Group Inc.
# 25   OPEN          Opendoor Technologies Inc.
# 26    SWN         Southwestern Energy Company
# 27    PFE                         Pfizer Inc.
# 28    HPE  Hewlett Packard Enterprise Company
# 29   JBLU         JetBlue Airways Corporation
#
#                                  address              city state         zip  \
# 0                       1200 17th Street            Denver    CO       80202
# 1                 265 Talbot Street West        Leamington    ON     N8H 5L4
# 2                           1 Tesla Road            Austin    TX       78725
# 3                 7373 Gateway Boulevard            Newark    CA       94560
# 4                     One Apple Park Way         Cupertino    CA       95014
# 5                            Building 20          Shanghai   N/A      201804
# 6                   2485 Augustine Drive       Santa Clara    CA       95054
# 7                 410 Terry Avenue North           Seattle    WA  98109-5210
# 8                      14600 Myford Road            Irvine    CA       92606
# 9                      One American Road          Dearborn    MI  48126-1899
# 10      Bank of America Corporate Center         Charlotte    NC       28255
# 11                208 South Akard Street            Dallas    TX       75202
# 12               1000 Urban Center Drive        Birmingham    AL  35242-2225
# 13             2788 San Tomas Expressway       Santa Clara    CA       95051
# 14                           One AMC Way           Leawood    KS       66211
# 15        2200 Mission College Boulevard       Santa Clara    CA  95054-1549
# 16  Praça Alfredo Egydio de Souza Aranha         São Paulo    SP   04344-902
# 17           One Johnson & Johnson Plaza     New Brunswick    NJ       08933
# 18                 Praia de Botafogo 186    Rio de Janeiro    RJ   22250-145
# 19                        234 1st Street     San Francisco    CA       94105
# 20                   101 NE Third Avenue   Fort Lauderdale    FL       33301
# 21                        620 8th Avenue          New York    NY       10018
# 22                     25 Gresham Street            London   N/A    EC2V 7HN
# 23         9601 South Meridian Boulevard         Englewood    CO       80112
# 24                       1 Skyview Drive        Fort Worth    TX       76155
# 25             410 North Scottsdale Road             Tempe    AZ       85281
# 26                    10000 Energy Drive            Spring    TX       77389
# 27              66 Hudson Boulevard East          New York    NY  10001-2192
# 28             1701 East Mossy Oaks Road            Spring    TX       77389
# 29              27-01 Queens Plaza North  Long Island City    NY       11101
#
#            country  Average Manager Age
# 0    United States                   46
# 1           Canada                   55
# 2    United States                   43
# 3    United States                   53
# 4    United States                   58
# 5            China                   50
# 6    United States                   57
# 7    United States                   56
# 8    United States                   47
# 9    United States                   57
# 10   United States                   55
# 11   United States                   54
# 12   United States                   58
# 13   United States                   60
# 14   United States                   55
# 15   United States                   55
# 16          Brazil                   48
# 17   United States                   56
# 18          Brazil                   53
# 19   United States                   51
# 20   United States                   51
# 21   United States                   48
# 22  United Kingdom                   55
# 23   United States                   58
# 24   United States                   55
# 25   United States                   45
# 26   United States                   51
# 27   United States                   58
# 28   United States                   56
# 29   United States                   46

# %%
yf.Ticker("AAPL").info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 164000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 61,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2022,
#    'totalPay': 16425933,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Luca  Maestri',
#    'age': 59,
#    'title': 'CFO & Sr. VP',
#    'yearBorn': 1963,
#    'fiscalYear': 2022,
#    'totalPay': 5019783,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 58,
#    'title': 'Chief Operating Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 5018337,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 58,
#    'title': 'Sr. VP, Gen. Counsel & Sec.',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 5015208,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 55,
#    'title': 'Sr. VP of Retail',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 5019783,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Sr. Director of Corp. Accounting',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James  Wilson',
#    'title': 'Chief Technology Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Mary  Demby',
#    'title': 'Chief Information Officer',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Nancy  Paxton',
#    'title': 'Sr. Director of Investor Relations & Treasury',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Sr. VP of Worldwide Marketing',
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 4,
#  'boardRisk': 1,
#  'compensationRisk': 5,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1690848000,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 178.85,
#  'open': 179.69,
#  'dayLow': 177.58,
#  'dayHigh': 180.27,
#  'regularMarketPreviousClose': 178.85,
#  'regularMarketOpen': 179.69,
#  'regularMarketDayLow': 177.58,
#  'regularMarketDayHigh': 180.27,
#  'dividendRate': 0.96,
#  'dividendYield': 0.0053,
#  'exDividendDate': 1683849600,
#  'payoutRatio': 0.156,
#  'fiveYearAvgDividendYield': 0.87,
#  'beta': 1.286802,
#  'trailingPE': 30.526318,
#  'forwardPE': 30.06689,
#  'volume': 67690988,
#  'regularMarketVolume': 67690988,
#  'averageVolume': 56642391,
#  'averageVolume10days': 57938530,
#  'averageDailyVolume10Day': 57938530,
#  'bid': 179.72,
#  'ask': 179.79,
#  'bidSize': 1800,
#  'askSize': 1200,
#  'marketCap': 2828020482048,
#  'fiftyTwoWeekLow': 124.17,
#  'fiftyTwoWeekHigh': 198.23,
#  'priceToSalesTrailing12Months': 7.365922,
#  'fiftyDayAverage': 187.227,
#  'twoHundredDayAverage': 160.1889,
#  'trailingAnnualDividendRate': 0.93,
#  'trailingAnnualDividendYield': 0.0051998883,
#  'currency': 'USD',
#  'enterpriseValue': 2892071960576,
#  'profitMargins': 0.24681,
#  'floatShares': 15617347029,
#  'sharesOutstanding': 15728700416,
#  'sharesShort': 126626604,
#  'sharesShortPriorMonth': 121254451,
#  'sharesShortPreviousMonthDate': 1686787200,
#  'dateShortInterest': 1689292800,
#  'sharesPercentSharesOut': 0.0081,
#  'heldPercentInsiders': 0.00071999995,
#  'heldPercentInstitutions': 0.61317,
#  'shortRatio': 2.35,
#  'shortPercentOfFloat': 0.0081,
#  'impliedSharesOutstanding': 15728700416,
#  'bookValue': 3.852,
#  'priceToBook': 46.67705,
#  'lastFiscalYearEnd': 1663977600,
#  'nextFiscalYearEnd': 1695513600,
#  'mostRecentQuarter': 1688169600,
#  'earningsQuarterlyGrowth': 0.023,
#  'netIncomeToCommon': 94760001536,
#  'trailingEps': 5.89,
#  'forwardEps': 5.98,
#  'pegRatio': 5.63,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 7.533,
#  'enterpriseToEbitda': 23.331,
#  '52WeekChange': 0.084465146,
#  'SandP52WeekChange': 0.09605169,
#  'lastDividendValue': 0.24,
#  'lastDividendDate': 1683849600,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'underlyingSymbol': 'AAPL',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'firstTradeDateEpochUtc': 345479400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'messageBoardId': 'finmb_24937',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 179.8,
#  'targetHighPrice': 218.13,
#  'targetLowPrice': 135.42,
#  'targetMeanPrice': 182.85,
#  'targetMedianPrice': 182.68,
#  'recommendationMean': 2.0,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 40,
#  'totalCash': 62482001920,
#  'totalCashPerShare': 3.996,
#  'ebitda': 123957002240,
#  'totalDebt': 109280002048,
#  'quickRatio': 0.814,
#  'currentRatio': 0.982,
#  'totalRevenue': 383932989440,
#  'debtToEquity': 181.305,
#  'revenuePerShare': 24.22,
#  'returnOnAssets': 0.20896,
#  'returnOnEquity': 1.60093,
#  'grossProfits': 170782000000,
#  'freeCashflow': 90680500224,
#  'operatingCashflow': 113071996928,
#  'earningsGrowth': 0.05,
#  'revenueGrowth': -0.014,
#  'grossMargins': 0.43449003,
#  'ebitdaMargins': 0.32286,
#  'operatingMargins': 0.29231,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.2936}

# %%
top_30_stock_info = pd.DataFrame()

# %%
data = yf.Ticker("AAPL").history(start="2018-01-01", end="2023-06-30")

# Resample the data to a quarterly frequency, taking the last day's data for each quarter
quarterly_data = data.resample('Q').last()

# Sort data in descending order
data_sorted = quarterly_data.sort_index(ascending=False)

top_30_stock_info["Date"] = data_sorted.index

top_30_stock_info.set_index("Date", inplace=True)

top_30_stock_info["AAPL Price"] = data_sorted["Close"]

for ticker in top_30_tickers:
    if ticker != "AAPL":
        data = yf.Ticker(ticker).history(start="2018-01-01", end="2023-06-30")
        quarterly_data = data.resample('Q').last()
        data_sorted = quarterly_data.sort_index(ascending=False)
        top_30_stock_info[ticker + " Price"] = data_sorted["Close"]

top_30_stock_info.head()
# Out:
#                            AAPL Price  PLTR Price  TLRY Price  TSLA Price  \
# Date
# 2023-06-30 00:00:00-04:00  189.589996       15.20        1.61  257.500000
# 2023-03-31 00:00:00-04:00  164.672226        8.45        2.53  207.460007
# 2022-12-31 00:00:00-05:00  129.552719        6.42        2.69  123.180000
# 2022-09-30 00:00:00-04:00  137.570480        8.13        2.75  265.250000
# 2022-06-30 00:00:00-04:00  135.908463        9.07        3.12  224.473328
#
#                            LCID Price  NIO Price   AMD Price  AMZN Price  \
# Date
# 2023-06-30 00:00:00-04:00        6.88   9.390000  111.239998  127.900002
# 2023-03-31 00:00:00-04:00        8.04  10.510000   98.010002  103.290001
# 2022-12-31 00:00:00-05:00        6.83   9.750000   64.769997   84.000000
# 2022-09-30 00:00:00-04:00       13.97  15.770000   63.360001  113.000000
# 2022-06-30 00:00:00-04:00       17.16  21.719999   76.470001  106.209999
#
#                            RIVN Price    F Price  ...  MARA Price  DDOG Price  \
# Date                                              ...
# 2023-06-30 00:00:00-04:00       16.01  14.789017  ...       13.82   96.449997
# 2023-03-31 00:00:00-04:00       15.48  12.310568  ...        8.72   72.660004
# 2022-12-31 00:00:00-05:00       18.43  10.688996  ...        3.42   73.500000
# 2022-09-30 00:00:00-04:00       32.91  10.187301  ...       10.71   88.779999
# 2022-06-30 00:00:00-04:00       25.74  10.023660  ...        5.34   95.239998
#
#                            LYG Price  DISH Price  AAL Price  OPEN Price  \
# Date
# 2023-06-30 00:00:00-04:00   2.083527        6.69      17.60        4.08
# 2023-03-31 00:00:00-04:00   2.196836        9.33      14.75        1.76
# 2022-12-31 00:00:00-05:00   2.083206       14.04      12.72        1.16
# 2022-09-30 00:00:00-04:00   1.694973       13.83      12.04        3.11
# 2022-06-30 00:00:00-04:00   1.897457       17.93      12.68        4.71
#
#                            SWN Price  PFE Price  HPE Price  JBLU Price
# Date
# 2023-06-30 00:00:00-04:00       5.92  35.722012  16.650000        8.76
# 2023-03-31 00:00:00-04:00       5.00  39.918495  15.815120        7.28
# 2022-12-31 00:00:00-05:00       5.85  49.676876  15.708212        6.48
# 2022-09-30 00:00:00-04:00       6.12  42.064533  11.704515        6.63
# 2022-06-30 00:00:00-04:00       6.25  50.010563  12.838717        8.37
#
# [5 rows x 30 columns]

# %%
top_30_volume = pd.DataFrame()

data = yf.Ticker("AAPL").history(start="2018-01-01", end="2023-06-30")

# Resample the data to a quarterly frequency, taking the last day's data for each quarter
quarterly_data = data.resample('Q').last()

# Sort data in descending order
data_sorted = quarterly_data.sort_index(ascending=False)

top_30_volume["Date"] = data_sorted.index

top_30_volume.set_index("Date", inplace=True)

top_30_volume["AAPL Volume"] = data_sorted["Volume"]

for ticker in top_30_tickers:
    if ticker != "AAPL":
        data = yf.Ticker(ticker).history(start="2018-01-01", end="2023-06-30")
        quarterly_data = data.resample('Q').last()
        data_sorted = quarterly_data.sort_index(ascending=False)
        top_30_volume[ticker + " Volume"] = data_sorted["Volume"]

top_30_volume.head()
# Out:
#                            AAPL Volume  PLTR Volume  TLRY Volume  TSLA Volume  \
# Date
# 2023-06-30 00:00:00-04:00     46347300   46300900.0   12202900.0    131283400
# 2023-03-31 00:00:00-04:00     68749800   26174800.0    6631600.0    170222100
# 2022-12-31 00:00:00-05:00     77034200   27830900.0   12088000.0    157777300
# 2022-09-30 00:00:00-04:00    124925300   47454800.0   11862200.0     67726600
# 2022-06-30 00:00:00-04:00     98964500   33636400.0   23981700.0     94600500
#
#                            LCID Volume  NIO Volume  AMD Volume  AMZN Volume  \
# Date
# 2023-06-30 00:00:00-04:00   72430500.0  38589900.0    58347200     40761000
# 2023-03-31 00:00:00-04:00   19553600.0  35906300.0    55861100     56750300
# 2022-12-31 00:00:00-05:00   22489800.0  40863800.0    37127000     62401200
# 2022-09-30 00:00:00-04:00   12259300.0  39341300.0    81664100     59479600
# 2022-06-30 00:00:00-04:00   13188800.0  53074100.0   105368600     97679400
#
#                            RIVN Volume  F Volume  ...  MARA Volume  \
# Date                                              ...
# 2023-06-30 00:00:00-04:00   48833700.0  58488600  ...     50628000
# 2023-03-31 00:00:00-04:00   38244700.0  66868200  ...     36159700
# 2022-12-31 00:00:00-05:00   17181800.0  39232200  ...      9615000
# 2022-09-30 00:00:00-04:00   12381000.0  71688200  ...     20135100
# 2022-06-30 00:00:00-04:00   11633000.0  59238200  ...     10706100
#
#                            DDOG Volume  LYG Volume  DISH Volume  AAL Volume  \
# Date
# 2023-06-30 00:00:00-04:00    2717400.0     4042600      9290800    20315700
# 2023-03-31 00:00:00-04:00    6681500.0     5849100      6515700    12348700
# 2022-12-31 00:00:00-05:00    2186700.0     4014100      2984300    19002800
# 2022-09-30 00:00:00-04:00    4006100.0    22843200      4709200    30111400
# 2022-06-30 00:00:00-04:00    4417300.0    11398500      3417700    37521400
#
#                            OPEN Volume  SWN Volume  PFE Volume  HPE Volume  \
# Date
# 2023-06-30 00:00:00-04:00   38306500.0    25487700    26284900     8779800
# 2023-03-31 00:00:00-04:00   22883800.0    16145100    23393600    15543500
# 2022-12-31 00:00:00-05:00   21507400.0    13152300    11396200     9396400
# 2022-09-30 00:00:00-04:00   11036300.0    30628900    22962300    13870500
# 2022-06-30 00:00:00-04:00   10892200.0    63826300    33495700    13551500
#
#                            JBLU Volume
# Date
# 2023-06-30 00:00:00-04:00     10709400
# 2023-03-31 00:00:00-04:00      6071500
# 2022-12-31 00:00:00-05:00      7481100
# 2022-09-30 00:00:00-04:00     13191800
# 2022-06-30 00:00:00-04:00     11031000
#
# [5 rows x 30 columns]

# %%
income_df = pd.DataFrame({
    'Quarter': ['2023-06-30', '2023-03-31', '2022-12-31', '2022-09-30', '2022-06-30']
})

income_df.set_index('Quarter', inplace=True)

for ticker in top_30_tickers:
    income_df[ticker + " Total Revenue"] = yf.Ticker(ticker).quarterly_income_stmt.loc["Total Revenue"]

income_df.loc['2023-06-30', 'TLRY Total Revenue'] = 184188000.0
income_df.loc['2023-03-31', 'TLRY Total Revenue'] = 145589000.0
income_df.loc['2022-12-31', 'TLRY Total Revenue'] = 144136000.0
income_df.loc['2022-09-30', 'TLRY Total Revenue'] = 153211000.0
income_df.loc['2022-06-30', 'TLRY Total Revenue'] = 153325000.0

income_df.loc['2023-06-30', 'HPE Total Revenue'] = 6973000000.0
income_df.loc['2023-03-31', 'HPE Total Revenue'] = 7809000000.0
income_df.loc['2022-12-31', 'HPE Total Revenue'] = 7871000000.0
income_df.loc['2022-09-30', 'HPE Total Revenue'] = 6951000000.0

# %%
yf.Ticker('HPE').quarterly_income_stmt
# Out:
#                                                           2023-04-30  \
# Tax Effect Of Unusual Items                         -16337164.750958
# Tax Rate For Calcs                                          0.199234
# Normalized EBITDA                                       1341000000.0
# Total Unusual Items                                      -82000000.0
# Total Unusual Items Excluding Goodwill                   -82000000.0
# Net Income From Continuing Operation Net Minori...       418000000.0
# Reconciled Depreciation                                  651000000.0
# Reconciled Cost Of Revenue                              3881000000.0
# EBIT                                                     608000000.0
# Net Interest Income                                      -54000000.0
# Interest Expense                                                 NaN
# Normalized Income                                   483662835.249042
# Net Income From Continuing And Discontinued Ope...       418000000.0
# Total Expenses                                          6365000000.0
# Total Operating Income As Reported                       520000000.0
# Diluted Average Shares                                  1318000000.0
# Basic Average Shares                                    1304000000.0
# Diluted EPS                                                     0.32
# Basic EPS                                                       0.32
# Diluted NI Availto Com Stockholders                      418000000.0
# Net Income Common Stockholders                           418000000.0
# Net Income                                               418000000.0
# Net Income Including Noncontrolling Interests            418000000.0
# Net Income Continuous Operations                         418000000.0
# Tax Provision                                            104000000.0
# Pretax Income                                            522000000.0
# Other Income Expense                                     -32000000.0
# Other Non Operating Income Expenses                        1000000.0
# Special Income Charges                                   -82000000.0
# Other Special Charges                                      3000000.0
# Impairment Of Capital Assets                                     NaN
# Restructuring And Mergern Acquisition                     79000000.0
# Earnings From Equity Interest                             49000000.0
# Net Non Operating Interest Income Expense                -54000000.0
# Total Other Finance Cost                                  54000000.0
# Interest Expense Non Operating                                   NaN
# Operating Income                                         608000000.0
# Operating Expense                                       1904000000.0
# Other Taxes                                               -6000000.0
# Depreciation Amortization Depletion Income Stat...        71000000.0
# Depreciation And Amortization In Income Statement         71000000.0
# Amortization                                              71000000.0
# Amortization Of Intangibles Income Statement              71000000.0
# Research And Development                                 570000000.0
# Selling General And Administration                      1269000000.0
# Gross Profit                                            2512000000.0
# Cost Of Revenue                                         4461000000.0
# Total Revenue                                           6973000000.0
# Operating Revenue                                       6973000000.0
#
#                                                           2023-01-31  \
# Tax Effect Of Unusual Items                         -22324237.560193
# Tax Rate For Calcs                                          0.195827
# Normalized EBITDA                                       1418000000.0
# Total Unusual Items                                     -114000000.0
# Total Unusual Items Excluding Goodwill                  -114000000.0
# Net Income From Continuing Operation Net Minori...       501000000.0
# Reconciled Depreciation                                  656000000.0
# Reconciled Cost Of Revenue                              4568000000.0
# EBIT                                                     648000000.0
# Net Interest Income                                      -25000000.0
# Interest Expense                                          25000000.0
# Normalized Income                                   592675762.439807
# Net Income From Continuing And Discontinued Ope...       501000000.0
# Total Expenses                                          7105000000.0
# Total Operating Income As Reported                       591000000.0
# Diluted Average Shares                                  1315000000.0
# Basic Average Shares                                    1298000000.0
# Diluted EPS                                                     0.38
# Basic EPS                                                       0.39
# Diluted NI Availto Com Stockholders                      501000000.0
# Net Income Common Stockholders                           501000000.0
# Net Income                                               501000000.0
# Net Income Including Noncontrolling Interests            501000000.0
# Net Income Continuous Operations                         501000000.0
# Tax Provision                                            122000000.0
# Pretax Income                                            623000000.0
# Other Income Expense                                     -56000000.0
# Other Non Operating Income Expenses                              NaN
# Special Income Charges                                  -114000000.0
# Other Special Charges                                      1000000.0
# Impairment Of Capital Assets                                     0.0
# Restructuring And Mergern Acquisition                    113000000.0
# Earnings From Equity Interest                             58000000.0
# Net Non Operating Interest Income Expense                -25000000.0
# Total Other Finance Cost                                         NaN
# Interest Expense Non Operating                            25000000.0
# Operating Income                                         704000000.0
# Operating Expense                                       1954000000.0
# Other Taxes                                                1000000.0
# Depreciation Amortization Depletion Income Stat...        73000000.0
# Depreciation And Amortization In Income Statement         73000000.0
# Amortization                                              73000000.0
# Amortization Of Intangibles Income Statement              73000000.0
# Research And Development                                 623000000.0
# Selling General And Administration                      1257000000.0
# Gross Profit                                            2658000000.0
# Cost Of Revenue                                         5151000000.0
# Total Revenue                                           7809000000.0
# Operating Revenue                                       7809000000.0
#
#                                                           2022-10-31  \
# Tax Effect Of Unusual Items                        -160633053.221289
# Tax Rate For Calcs                                          0.148459
# Normalized EBITDA                                       2423000000.0
# Total Unusual Items                                    -1082000000.0
# Total Unusual Items Excluding Goodwill                 -1082000000.0
# Net Income From Continuing Operation Net Minori...      -304000000.0
# Reconciled Depreciation                                  618000000.0
# Reconciled Cost Of Revenue                              4733000000.0
# EBIT                                                     723000000.0
# Net Interest Income                                     -109000000.0
# Interest Expense                                         109000000.0
# Normalized Income                                   617366946.778711
# Net Income From Continuing And Discontinued Ope...      -304000000.0
# Total Expenses                                          7148000000.0
# Total Operating Income As Reported                      -339000000.0
# Diluted Average Shares                                  1296000000.0
# Basic Average Shares                                    1296000000.0
# Diluted EPS                                                    -0.23
# Basic EPS                                                      -0.23
# Diluted NI Availto Com Stockholders                     -304000000.0
# Net Income Common Stockholders                          -304000000.0
# Net Income                                              -304000000.0
# Net Income Including Noncontrolling Interests           -304000000.0
# Net Income Continuous Operations                        -304000000.0
# Tax Provision                                            -53000000.0
# Pretax Income                                           -357000000.0
# Other Income Expense                                    -971000000.0
# Other Non Operating Income Expenses                       28000000.0
# Special Income Charges                                 -1082000000.0
# Other Special Charges                                     -1000000.0
# Impairment Of Capital Assets                             905000000.0
# Restructuring And Mergern Acquisition                    178000000.0
# Earnings From Equity Interest                             83000000.0
# Net Non Operating Interest Income Expense               -109000000.0
# Total Other Finance Cost                                 109000000.0
# Interest Expense Non Operating                           109000000.0
# Operating Income                                         723000000.0
# Operating Expense                                       1870000000.0
# Other Taxes                                               20000000.0
# Depreciation Amortization Depletion Income Stat...        73000000.0
# Depreciation And Amortization In Income Statement         73000000.0
# Amortization                                              73000000.0
# Amortization Of Intangibles Income Statement              73000000.0
# Research And Development                                 515000000.0
# Selling General And Administration                      1262000000.0
# Gross Profit                                            2593000000.0
# Cost Of Revenue                                         5278000000.0
# Total Revenue                                           7871000000.0
# Operating Revenue                                       7871000000.0
#
#                                                           2022-07-31
# Tax Effect Of Unusual Items                         -14105603.448276
# Tax Rate For Calcs                                          0.118534
# Normalized EBITDA                                       1294000000.0
# Total Unusual Items                                     -119000000.0
# Total Unusual Items Excluding Goodwill                  -119000000.0
# Net Income From Continuing Operation Net Minori...       409000000.0
# Reconciled Depreciation                                  620000000.0
# Reconciled Cost Of Revenue                              4008000000.0
# EBIT                                                     555000000.0
# Net Interest Income                                      -74000000.0
# Interest Expense                                          74000000.0
# Normalized Income                                   513894396.551724
# Net Income From Continuing And Discontinued Ope...       409000000.0
# Total Expenses                                          6396000000.0
# Total Operating Income As Reported                       466000000.0
# Diluted Average Shares                                  1323000000.0
# Basic Average Shares                                    1305000000.0
# Diluted EPS                                                     0.31
# Basic EPS                                                       0.31
# Diluted NI Availto Com Stockholders                      409000000.0
# Net Income Common Stockholders                           409000000.0
# Net Income                                               409000000.0
# Net Income Including Noncontrolling Interests            409000000.0
# Net Income Continuous Operations                         409000000.0
# Tax Provision                                             55000000.0
# Pretax Income                                            464000000.0
# Other Income Expense                                     -17000000.0
# Other Non Operating Income Expenses                       34000000.0
# Special Income Charges                                  -119000000.0
# Other Special Charges                                     30000000.0
# Impairment Of Capital Assets                                     NaN
# Restructuring And Mergern Acquisition                     89000000.0
# Earnings From Equity Interest                             68000000.0
# Net Non Operating Interest Income Expense                -74000000.0
# Total Other Finance Cost                                  74000000.0
# Interest Expense Non Operating                            74000000.0
# Operating Income                                         555000000.0
# Operating Expense                                       1841000000.0
# Other Taxes                                               30000000.0
# Depreciation Amortization Depletion Income Stat...        73000000.0
# Depreciation And Amortization In Income Statement         73000000.0
# Amortization                                              73000000.0
# Amortization Of Intangibles Income Statement              73000000.0
# Research And Development                                 509000000.0
# Selling General And Administration                      1229000000.0
# Gross Profit                                            2396000000.0
# Cost Of Revenue                                         4555000000.0
# Total Revenue                                           6951000000.0
# Operating Revenue                                       6951000000.0
