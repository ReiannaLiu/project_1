# %%
# Import Dependencies
import pandas as pd
import hvplot.pandas
import requests
import json
from holoviews import opts

# Import the API key
from api_keys import geoapify_key

# %%
# Import data from csv file
top_30_df = pd.read_csv('Resources/top_30_df.csv')

top_30_df.head()
# Out:
#   Ticker                     company                 address        city  \
# 0   PLTR  Palantir Technologies Inc.        1200 17th Street      Denver
# 1   TLRY         Tilray Brands, Inc.  265 Talbot Street West  Leamington
# 2   TSLA                 Tesla, Inc.            1 Tesla Road      Austin
# 3   LCID           Lucid Group, Inc.  7373 Gateway Boulevard      Newark
# 4   AAPL                  Apple Inc.      One Apple Park Way   Cupertino
#
#   state      zip        country  \
# 0    CO    80202  United States
# 1    ON  N8H 5L4         Canada
# 2    TX    78725  United States
# 3    CA    94560  United States
# 4    CA    95014  United States
#
#                                     address_combined  Average Manager Age
# 0  1200 17th Street, Denver, CO, 80202, United St...                   46
# 1  265 Talbot Street West, Leamington, ON, N8H 5L...                   55
# 2     1 Tesla Road, Austin, TX, 78725, United States                   45
# 3  7373 Gateway Boulevard, Newark, CA, 94560, Uni...                   53
# 4  One Apple Park Way, Cupertino, CA, 95014, Unit...                   58

# %%
# Initialize the columns for the dataframe
top_30_df["Lat"] = ""
top_30_df["Lng"] = ""

top_30_df.head()
# Out:
#   Ticker                     company                 address        city  \
# 0   PLTR  Palantir Technologies Inc.        1200 17th Street      Denver
# 1   TLRY         Tilray Brands, Inc.  265 Talbot Street West  Leamington
# 2   TSLA                 Tesla, Inc.            1 Tesla Road      Austin
# 3   LCID           Lucid Group, Inc.  7373 Gateway Boulevard      Newark
# 4   AAPL                  Apple Inc.      One Apple Park Way   Cupertino
#
#   state      zip        country  \
# 0    CO    80202  United States
# 1    ON  N8H 5L4         Canada
# 2    TX    78725  United States
# 3    CA    94560  United States
# 4    CA    95014  United States
#
#                                     address_combined  Average Manager Age Lat  \
# 0  1200 17th Street, Denver, CO, 80202, United St...                   46
# 1  265 Talbot Street West, Leamington, ON, N8H 5L...                   55
# 2     1 Tesla Road, Austin, TX, 78725, United States                   45
# 3  7373 Gateway Boulevard, Newark, CA, 94560, Uni...                   53
# 4  One Apple Park Way, Cupertino, CA, 95014, Unit...                   58
#
#   Lng
# 0
# 1
# 2
# 3
# 4

# %%
# Build URL using the geocode endpoint
base_url = "https://api.geoapify.com/v1/geocode/search"

# %%
for index, row in top_30_df.iterrows():
    params = {
        "text": row["address_combined"],
        "apiKey": geoapify_key,
        format: "json"
    }

    # Run request
    response = requests.get(base_url, params=params).json()

    # Extract lat/lng
    try:
        top_30_df.loc[index, "Lat"] = response["features"][0]["properties"]["lat"]
        top_30_df.loc[index, "Lng"] = response["features"][0]["properties"]["lon"]
    except:
        print(f"Cannot find lat/lng for {row['address_combined']}")

# %%
top_30_df
# Out:
#    Ticker                             company  \
# 0    PLTR          Palantir Technologies Inc.
# 1    TLRY                 Tilray Brands, Inc.
# 2    TSLA                         Tesla, Inc.
# 3    LCID                   Lucid Group, Inc.
# 4    AAPL                          Apple Inc.
# 5     NIO                            NIO Inc.
# 6     AMD        Advanced Micro Devices, Inc.
# 7    AMZN                    Amazon.com, Inc.
# 8    RIVN             Rivian Automotive, Inc.
# 8    United States  14600 Myford Road, Irvine, CA, 92606, United S...
# 9    United States  One American Road, Dearborn, MI, 48126-1899, U...
# 10   United States  Bank of America Corporate Center, Charlotte, N...
# 11   United States  208 South Akard Street, Dallas, TX, 75202, Uni...
# 12   United States  1000 Urban Center Drive, Birmingham, AL, 35242...
# 13   United States  2788 San Tomas Expressway, Santa Clara, CA, 95...
# 14   United States     One AMC Way, Leawood, KS, 66211, United States
# 15   United States  2200 Mission College Boulevard, Santa Clara, C...
# 16          Brazil  Praça Alfredo Egydio de Souza Aranha, São Paul...
# 17   United States  One Johnson & Johnson Plaza, New Brunswick, NJ...
# 18          Brazil  Praia de Botafogo 186, Rio de Janeiro, RJ, 222...
# 19   United States  234 1st Street, San Francisco, CA, 94105, Unit...
# 20   United States  101 NE Third Avenue, Fort Lauderdale, FL, 3330...
# 21   United States  620 8th Avenue, New York, NY, 10018, United St...
# 22  United Kingdom  25 Gresham Street, London, N/A, EC2V 7HN, Unit...
# 23   United States  9601 South Meridian Boulevard, Englewood, CO, ...
# 24   United States  1 Skyview Drive, Fort Worth, TX, 76155, United...
# 25   United States  410 North Scottsdale Road, Tempe, AZ, 85281, U...
# 26   United States  10000 Energy Drive, Spring, TX, 77389, United ...
# 27   United States  66 Hudson Boulevard East, New York, NY, 10001-...
# 28   United States  1701 East Mossy Oaks Road, Spring, TX, 77389, ...
# 29   United States  27-01 Queens Plaza North, Long Island City, NY...
#
#     Average Manager Age        Lat         Lng
# 0                    46  39.749488 -104.995521
# 1                    55  42.051302  -82.621871
# 2                    45  30.224762  -97.605674
# 3                    53  37.542222 -122.059929
# 4                    58  37.335041 -122.014386
# 5                    50  31.377111  121.245202
# 6                    57   37.38215 -121.971613
# 7                    56  47.622254 -122.337028
# 8                    47  33.711145 -117.803018
# 9                    57  42.317334  -83.208048
# 10                   55  35.150264  -80.836605
# 11                   54  32.779684   -96.79916
# 12                   58  33.484377  -86.704658
# 13                   60  37.371474 -121.967877
# 14                   55  38.892091  -94.626212
# 15                   55  37.387829 -121.963367
# 16                   48 -23.635841  -46.641821
# 17                   56  40.497888  -74.443092
# 18                   53 -22.940928  -43.179748
# 19                   51  37.787909 -122.395394
# 20                   51  26.123405  -80.140626
# 21                   48  40.756019  -73.990552
# 22                   55   51.51626    -0.09559
# 23                   58  39.545642 -104.856322
# 24                   55  32.825479  -97.065442
# 25                   45  33.433398 -111.926361
# 26                   51  30.099097  -95.436917
# 27                   58   40.75525  -73.999582
# 28                   56  30.100817  -95.477764
# 29                   46  40.750522  -73.938945

# %%
# Create the map plot using hvplot
map_plot = top_30_df.hvplot.points(
    x="Lng",
    y="Lat",
    geo=True,
    hover_cols=["city"],
    alpha=0.3,
    height=500,
    width=500,
    frame_width=500,
    frame_height=500,
    tiles="OSM"
)

# Set the initial view to center around the United States
map_plot = map_plot.redim.range(
    Lng=(-130, -60),  # Longitude range for the United States
    Lat=(24, 50)  # Latitude range for the United States
)

map_plot.opts(
    opts.Points(size=10, color='blue', tools=['hover']),
    opts.WMTS(alpha=0.5),
)
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (city)
